# %%
import xarray as xr
import numpy as np
import os
from glob import glob
from tqdm import tqdm
import pandas as pd
from geopy.distance import geodesic 
import math
from sklearn.metrics.pairwise import haversine_distances
from math import radians
from multiprocess import Pool
import warnings

# %%
from gstools import CovModel

class Stab(CovModel):
    def variogram(self, r):
        
        return self.nugget + self.sill * (1 - np.exp(-(3 * r) / self.len_scale))

# %%
from scipy.optimize import curve_fit

# Define the piecewise function
def custom_curve(h, c, b, alpha):
    if np.isscalar(h):
        # Handle the scalar case
        if h == 0:
            return 0
        else:
            return c + b * (1 - np.exp(-3 * h / alpha))
    else:
        # Handle array inputs
        return np.where(h == 0, 0, c + b * (1 - np.exp(-3 * h / alpha)))

def fit_sci_curve(h_values, y_values,bins):

    # Use curve_fit to fit the custom function to the data
    # Initial guess for c, b, and alpha
    initial_guess = [0, 0.5, 5]  
    
    # Perform the curve fitting
    params, covariance = curve_fit(custom_curve, h_values, y_values, p0=initial_guess)
    
    # Extract the fitted parameters
    c_fitted, b_fitted, alpha_fitted = params
    
    y_fit = custom_curve(bins, c_fitted, b_fitted, alpha_fitted)
    return y_fit, alpha_fitted

# %%
def calc_ratio_gamma(N11,N10):
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=RuntimeWarning)
        ratio = np.where(N10 + N11 != 0, 0.5 * (N10 / (N10 + N11)), np.nan)
        if len(ratio.shape)==2:
            ratio[:,0] = 0
        if len(ratio.shape)==1:
            ratio[0] = 0    
    return ratio

# %%
# Define distance bins
bins = np.arange(5, 360, 10)

# Function to calculate pairwise distances
def calculate_pairwise_distances(df):
    coords = df[['lat', 'lon']].applymap(radians).values  # Convert to radians for haversine
    distances = haversine_distances(coords) * 6371  # Earth radius in km
    return distances

# Function to calculate N11 and N10 pairs
def calculate_pairs(df, bins):
    distances = calculate_pairwise_distances(df)
    n = len(df)
    extreme = df['flag'].values
    N11 = np.zeros_like(bins, dtype=int)  # Array for 1-1 pairs
    N10 = np.zeros_like(bins, dtype=int)  # Array for 1-0 pairs

    for i in range(n):
        for j in range(i + 1, n):
            dist = distances[i, j]
            bin_idx = np.digitize(dist, bins) - 1
            if bin_idx >= 0 and bin_idx < len(bins):
                if extreme[i] > 0 and extreme[j] > 0:
                    N11[bin_idx] += 1
                elif (extreme[i] > 0 and extreme[j] == 0) or (extreme[i] == 0 and extreme[j] > 0):
                    N10[bin_idx] += 1

    return N11, N10

# %%
def calc_alpha(gamma_fit,bins_fit,bins):
    # gamma_fit = gamma[~np.isnan(gamma)]
    # bins_fit = bins[~np.isnan(bins)]
    y_fit = 0
    scale = 0
    try:
        _ = fit_model.fit_variogram(bins_fit, gamma_fit,  nugget=0, sill=0.5)#)#
        y_fit = fit_model.variogram(bins)
        scale = fit_model.len_scale
    except RuntimeError:
        try: 
            ## adjust the cape a little bit so the code can pass through
            _ = fit_model.fit_variogram(bins_fit, gamma_fit,  nugget=0, sill=0.51)#)#
            y_fit = fit_model.variogram(bins)
            scale = fit_model.len_scale
        except RuntimeError:
            y_fit,alpha = fit_sci_curve(bins_fit,gamma_fit,bins)
            no_fit_days.append(days)
            scale = alpha
    return y_fit, scale

# %%
def calc_pair_alpha(days):
    df = df_stations_p90[df_stations_p90["Day"]==days]
    if df["flag"].max() <=0:
        N11 = np.zeros_like(bins)
        N10 = np.zeros_like(bins)
        gamma = np.zeros_like(bins)
        y_fit = np.zeros_like(bins)
        scale = 0
    else:
        
        # Calculate N11 and N10 pairs
        N11, N10 = calculate_pairs(df, bins)
        gamma = calc_ratio_gamma(N11, N10)        
        gamma_fit = gamma.copy()
        bins_fit = bins.copy().astype(float)
        gamma_fit[N11+N10<=2] = np.nan
        bins_fit[N11+N10<=2] = np.nan
        ## make sure start with zeros
        # gamma_fit[0] = 0
        # bins_fit[0] =0
        ## remove NaNs 
        gamma_fit1 = gamma_fit[~np.isnan(gamma_fit)]
        bins_fit1 = bins_fit[~np.isnan(bins_fit)]
        ## in case all NaNs occured
        if len(gamma_fit1)<=2:
            y_fit = np.zeros_like(bins)
            scale = 0
        else:
            y_fit, scale = calc_alpha(gamma_fit1, bins_fit1, bins)
    local_bins_dict = {
        "Day": [days] * len(bins),
        "Date": [df_stations_p90["Date"][df_stations_p90["Day"]==days].values[0]] *len(bins),
        "Bins": bins.tolist(),
        "N11": N11.tolist(),
        "N10": N10.tolist(),
        "gamma": gamma.tolist(),
        "y_fit": y_fit.tolist()
    }
    return local_bins_dict, scale

# %%
## my own directory
os.chdir("/g/data/k10/dl6968/Semi-variogram_AU/")

# %%
fit_model = Stab(dim=2)#gs.Stable(dim=1)

# %%
files = sorted(glob("./data/all_AU_p90/*_station_list_all_events.csv"))

# %%
max_pool = 28
for file in tqdm(files[3500:], leave=True, position=0, total=len(files[3500:])):
    if not os.path.exists(file.replace("station","pair_scale")):
        df_stations_p90 = pd.read_csv(file)
        with Pool(max_pool) as p:
            pool_outputs = list(
                    p.imap(calc_pair_alpha,
                           np.unique(df_stations_p90["Day"])),
            )
        p.join()
        
        y_fit_arr = np.zeros((len(np.unique(df_stations_p90["Day"])), bins.shape[0]))
        N11_arr = np.zeros_like(y_fit_arr)
        N10_arr = np.zeros_like(y_fit_arr)
        gamma_arr = np.zeros_like(y_fit_arr)
        scale_arr = np.zeros(len(np.unique(df_stations_p90["Day"])))
        bins_dict = {"Day": [], "Date": [], "Bins": [], "N11": [], "N10": [], "gamma": [], "y_fit": []}
        for i in range(0, len(np.unique(df_stations_p90["Day"]))):
            scale_arr[i] = pool_outputs[i][1]
            for key in bins_dict:
                    bins_dict[key].extend(pool_outputs[i][0][key])
            
        scale_dict = {"extreme_dates": np.unique(df_stations_p90["Date"]), "scale": scale_arr}
        df_scale = pd.DataFrame.from_dict(scale_dict)
        df_scale.to_csv(file.replace("station","pair_scale"))
        
        df_bins =  pd.DataFrame.from_dict(bins_dict)
        df_bins.to_csv(file.replace("station","pair_bins"))
# Out:
#   7%|▋         | 418/5913 [2:11:19<28:46:24, 18.85s/it]Process ForkPoolWorker-41435:
# Exception ignored in: <generator object tqdm.__iter__ at 0x14dc16f7d890>
# Traceback (most recent call last):
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/tqdm/std.py", line 1302, in close
#     self.display(pos=0)
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/tqdm/std.py", line 1495, in display
#     self.sp(self.__str__() if msg is None else msg)
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/tqdm/std.py", line 459, in print_status
#     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/tqdm/std.py", line 453, in fp_write
#     fp_flush()
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/tqdm/utils.py", line 196, in inner
#     return func(*args, **kwargs)
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/ipykernel/iostream.py", line 609, in flush
#     if not evt.wait(self.flush_timeout):
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/threading.py", line 574, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/threading.py", line 316, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/jobfs/136269718.gadi-pbs/ipykernel_1207407/2165281437.py", line 12, in calc_pair_alpha
#     N11, N10 = calculate_pairs(df, bins)
#   File "/jobfs/136269718.gadi-pbs/ipykernel_1207407/3429222432.py", line 12, in calculate_pairs
#     distances = calculate_pairwise_distances(df)
#   File "/jobfs/136269718.gadi-pbs/ipykernel_1207407/3429222432.py", line 7, in calculate_pairwise_distances
#     distances = haversine_distances(coords) * 6371  # Earth radius in km
#   File "/home/565/dl6968/miniconda3/envs/myenv/lib/python3.9/site-packages/sklearn/metrics/pairwise.py", line 723, in haversine_distances
#     return DistanceMetric.get_metric('haversine').pairwise(X, Y)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/pool.py:853, in IMapIterator.next(self, timeout)
#     852 try:
# --> 853     item = self._items.popleft()
#     854 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       5 with Pool(max_pool) as p:
# ----> 6     pool_outputs = list(
#       7             p.imap(calc_pair_alpha,
#       8                    np.unique(df_stations_p90["Day"])),
#       9     )
#      10 p.join()
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/pool.py:858, in IMapIterator.next(self, timeout)
#     857     raise StopIteration from None
# --> 858 self._cond.wait(timeout)
#     859 try:
#
# File ~/miniconda3/envs/myenv/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     311 if timeout is None:
# --> 312     waiter.acquire()
#     313     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       4 df_stations_p90 = pd.read_csv(file)
#       5 with Pool(max_pool) as p:
# ----> 6     pool_outputs = list(
#       7             p.imap(calc_pair_alpha,
#       8                    np.unique(df_stations_p90["Day"])),
#       9     )
#      10 p.join()
#      12 y_fit_arr = np.zeros((len(np.unique(df_stations_p90["Day"])), bins.shape[0]))
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/pool.py:736, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     735 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 736     self.terminate()
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/pool.py:654, in Pool.terminate(self)
#     652 util.debug('terminating pool')
#     653 self._state = TERMINATE
# --> 654 self._terminate()
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/util.py:224, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     221 else:
#     222     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223               self._callback, self._args, self._kwargs)
# --> 224     res = self._callback(*self._args, **self._kwargs)
#     225 self._weakref = self._callback = self._args = \
#     226                 self._kwargs = self._key = None
#     227 return res
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/pool.py:687, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     683 # Notify that the worker_handler state has been changed so the
#     684 # _handle_workers loop can be unblocked (and exited) in order to
#     685 # send the finalization sentinel all the workers.
#     686 worker_handler._state = TERMINATE
# --> 687 change_notifier.put(None)
#     689 task_handler._state = TERMINATE
#     691 util.debug('helping task handler/workers to finish')
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/queues.py:379, in SimpleQueue.put(self, obj)
#     377     self._writer.send_bytes(obj)
#     378 else:
# --> 379     with self._wlock:
#     380         self._writer.send_bytes(obj)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/multiprocess/synchronize.py:101, in SemLock.__enter__(self)
#     100 def __enter__(self):
# --> 101     return self._semlock.__enter__()
#
# KeyboardInterrupt:
